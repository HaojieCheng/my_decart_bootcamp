# %% [markdown]
# ## Visualizing Spatial Data with Pandas and Bokeh

# %% [markdown]
# [bokeh](http://bokeh.pydata.org/en/latest/) is a relatively new JavaScript visualization language for Python that is modeled after D3 but is intended to be able to handle millions of data points.
#
# >Bokeh is a Python interactive visualization library that targets modern web browsers for presentation. Its goal is to provide elegant, concise construction of novel graphics in the style of D3.js, and to extend this capability with high-performance interactivity over very large or streaming datasets. Bokeh can help anyone who would like to quickly and easily create interactive plots, dashboards, and data applications. ([Bokeh Website](http://bokeh.pydata.org/en/latest/))
#
# The advantage of Bokeh over matplotlib is that the visualizations can be interactive (via the JavaScript).
#
# From the U.K. accident data, we can plot the location of accidents for which latitude and longitude values are provided.

# %%
import os
import sqlite3 as sqlite
DATADIR = os.path.join(os.path.expanduser("~"),"DATA",
                       "Misc")
print(os.path.exists(DATADIR))
import pandas as pd
import numpy as np
# Out:
# True

# %%
from bokeh.io import output_notebook

# %% [markdown]
# ### This enables drawing directly in the notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9a35fe98-f6af-4efc-9999-8b423fbdb052">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Read in the data

# %%
data = pd.read_csv(os.path.join(DATADIR,
                         "Accidents7904.csv"),
                   usecols = ['Longitude',"Latitude","Date"]).dropna()#drop any row with missing value
data.head()
# Out:
#          Longitude   Latitude        Date
# 4883216  -0.271752  51.715661  25/12/1999
# 4883217  -0.239977  51.695136  17/12/1999
# 4883218  -0.270037  51.715096  15/12/1999
# 4883219  -0.263233  51.711309  02/12/1999
# 4883220  -0.227225  51.688200  04/12/1999

# %%
data.dtypes #panda can recognize object
# Out:
# Longitude    float64
# Latitude     float64
# Date          object
# dtype: object

# %% [markdown]
# ####  We can use the [``sample``](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sample.html) method to get a subset of DataFrame

# %%
subdata = data.sample(2000)
mean_long = np.mean(subdata['Longitude'])
mean_lat  = np.mean(subdata['Latitude'])

# %%
from bokeh.io import output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, 
    PanTool, WheelZoomTool, BoxSelectTool, HoverTool
)

hover = HoverTool()
map_options = GMapOptions(lat=mean_lat, 
                          lng=mean_long, 
                          map_type="roadmap", zoom=6)

plot = GMapPlot(
    x_range=DataRange1d(), 
    y_range=DataRange1d(), 
    map_options=map_options
)
plot.title.text = "U.K. Road Accidents"

source = ColumnDataSource(
    data=dict(
        lat=subdata['Latitude'],
        lon=subdata['Longitude'],
    )
)


hover.tooltips.append(('index','$index'))
circle = Circle(x="lon", y="lat", size=2, 
                fill_color="blue", fill_alpha=0.8, 
                line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(),WheelZoomTool(), BoxSelectTool(), hover)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="50ac48e3-3148-4973-b6c9-a738a80e0758"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("50ac48e3-3148-4973-b6c9-a738a80e0758");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("50ac48e3-3148-4973-b6c9-a738a80e0758");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '50ac48e3-3148-4973-b6c9-a738a80e0758' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"57db6411-b2d1-4881-b3cc-bcc1eaf9c76c":{"roots":{"references":[{"attributes":{"plot":{"id":"1138551e-e10c-429b-8bb3-f84dda1f00c1","type":"GMapPlot"}},"id":"2d3b2a61-62b1-4689-8f8c-0ac79ac6e7ff","type":"PanTool"},{"attributes":{"lat":52.649524781500006,"lng":-1.4708179665000003,"zoom":6},"id":"93fb60b8-a38f-480e-941c-5c11721ef673","type":"GMapOptions"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5078add7-b01b-45eb-9f8e-9c29c5220a55","type":"BoxAnnotation"},{"attributes":{"map_options":{"id":"93fb60b8-a38f-480e-941c-5c11721ef673","type":"GMapOptions"},"renderers":[{"id":"7a855400-fadc-481a-a2c7-b7fb5dfe0bad","type":"GlyphRenderer"},{"id":"5078add7-b01b-45eb-9f8e-9c29c5220a55","type":"BoxAnnotation"}],"title":{"id":"5c86f231-a01e-4b4d-a3c9-b143647000d6","type":"Title"},"tool_events":{"id":"7b46bd9e-a1c3-4dd0-8a19-90e58aded749","type":"ToolEvents"},"toolbar":{"id":"1f5d614c-4e35-4d50-8ac1-b602ee85220e","type":"Toolbar"},"x_range":{"id":"4f23dce6-8b66-4e7d-a6a1-75ee9640d8cf","type":"DataRange1d"},"y_range":{"id":"fb7d6b28-d76b-43c0-a35c-f4f8af9395c6","type":"DataRange1d"}},"id":"1138551e-e10c-429b-8bb3-f84dda1f00c1","type":"GMapPlot"},{"attributes":{"callback":null,"overlay":{"id":"5078add7-b01b-45eb-9f8e-9c29c5220a55","type":"BoxAnnotation"},"plot":{"id":"1138551e-e10c-429b-8bb3-f84dda1f00c1","type":"GMapPlot"}},"id":"343415bc-525f-4edc-b2e6-99e7a0362eb9","type":"BoxSelectTool"},{"attributes":{"callback":null},"id":"fb7d6b28-d76b-43c0-a35c-f4f8af9395c6","type":"DataRange1d"},{"attributes":{"plot":null,"text":"U.K. Road Accidents"},"id":"5c86f231-a01e-4b4d-a3c9-b143647000d6","type":"Title"},{"attributes":{"plot":{"id":"1138551e-e10c-429b-8bb3-f84dda1f00c1","type":"GMapPlot"}},"id":"72caae44-3efa-4c4f-b86e-135937d78c78","type":"WheelZoomTool"},{"attributes":{"callback":null,"plot":{"id":"1138551e-e10c-429b-8bb3-f84dda1f00c1","type":"GMapPlot"}},"id":"cea7cc0e-07ce-4e13-870f-c4eb3a1778e7","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":{"__ndarray__":"...","dtype":"float64","shape":[2000]},"lon":{"__ndarray__":"...","dtype":"float64","shape":[2000]}}},"id":"f8923f58-43ef-4b4d-9ef9-587c4bb9fec6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f8923f58-43ef-4b4d-9ef9-587c4bb9fec6","type":"ColumnDataSource"},"glyph":{"id":"48809489-d4ae-43a1-b446-128f63ad7543","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"7a855400-fadc-481a-a2c7-b7fb5dfe0bad","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"4f23dce6-8b66-4e7d-a6a1-75ee9640d8cf","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":2},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"48809489-d4ae-43a1-b446-128f63ad7543","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2d3b2a61-62b1-4689-8f8c-0ac79ac6e7ff","type":"PanTool"},{"id":"72caae44-3efa-4c4f-b86e-135937d78c78","type":"WheelZoomTool"},{"id":"343415bc-525f-4edc-b2e6-99e7a0362eb9","type":"BoxSelectTool"},{"id":"cea7cc0e-07ce-4e13-870f-c4eb3a1778e7","type":"HoverTool"}]},"id":"1f5d614c-4e35-4d50-8ac1-b602ee85220e","type":"Toolbar"},{"attributes":{},"id":"7b46bd9e-a1c3-4dd0-8a19-90e58aded749","type":"ToolEvents"}],"root_ids":["1138551e-e10c-429b-8bb3-f84dda1f00c1"]},"title":"Bokeh Application","version":"0.12.5"}};
#             var render_items = [{"docid":"57db6411-b2d1-4881-b3cc-bcc1eaf9c76c","elementid":"50ac48e3-3148-4973-b6c9-a738a80e0758","modelid":"1138551e-e10c-429b-8bb3-f84dda1f00c1"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_loa
